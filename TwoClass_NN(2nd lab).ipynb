# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
import matplotlib.pyplot as plt
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
gray_scale = 255 
x_train /= gray_scale
x_test /= gray_scale
print("--- Data Structure ---")
print("Feature matrix (train):", x_train.shape)
print("Target matrix (train):", y_train.shape)
print("Feature matrix (test):", x_test.shape)
print("Target matrix (test):", y_test.shape)
print("------------------------\n")
print("--- Visualizing Data (Close window to continue) ---")
fig, ax = plt.subplots(10, 10)
k = 0
for i in range(10):
    for j in range(10):
        ax[i][j].imshow(x_train[k].reshape(28, 28), aspect='auto', cmap='gray')
        k += 1
plt.show()
print("--------------------------------------------------\n")
model = Sequential([
# reshape 28 row * 28 column data to 28*28 rows
Flatten(input_shape=(28, 28)),
# dense layer 1
Dense(256, activation='sigmoid'),
# dense layer 2
Dense(128, activation='sigmoid'),
# output layer
Dense(10, activation='sigmoid'),
])
model.compile(optimizer='adam',
  loss='sparse_categorical_crossentropy',
  metrics=['accuracy'])
print("--- Model Summary ---")
model.summary()
print("---------------------\n")
print("--- Training Model ---")
model.fit(x_train, y_train, epochs=10, batch_size=2000, validation_split=0.2)
print("----------------------\n")
print("--- Evaluating Model ---")
results = model.evaluate(x_test, y_test, verbose=0)
print('Test loss, Test acc:', results)
print("------------------------\n")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# --- Data Structure ---
# Feature matrix (train): (60000, 28, 28)
# Target matrix (train): (60000,)
# Feature matrix (test): (10000, 28, 28)
# Target matrix (test): (10000,)
# ------------------------
#
# --- Visualizing Data (Close window to continue) ---
# --------------------------------------------------
# c:\Users\Shreyas Holkar\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# --- Model Summary ---
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 235,146 (918.54 KB)
#  Trainable params: 235,146 (918.54 KB)
#  Non-trainable params: 0 (0.00 B)
# ---------------------
#
# --- Training Model ---
# Epoch 1/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.3936 - loss: 2.0579 - val_accuracy: 0.7142 - val_loss: 1.6868
# Epoch 2/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7237 - loss: 1.3519 - val_accuracy: 0.7928 - val_loss: 1.0083
# Epoch 3/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8111 - loss: 0.8488 - val_accuracy: 0.8587 - val_loss: 0.6654
# Epoch 4/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8636 - loss: 0.5996 - val_accuracy: 0.8876 - val_loss: 0.4929
# Epoch 5/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8867 - loss: 0.4693 - val_accuracy: 0.9014 - val_loss: 0.4027
# Epoch 6/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8992 - loss: 0.3968 - val_accuracy: 0.9088 - val_loss: 0.3514
# Epoch 7/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9077 - loss: 0.3521 - val_accuracy: 0.9148 - val_loss: 0.3184
# Epoch 8/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9132 - loss: 0.3215 - val_accuracy: 0.9193 - val_loss: 0.2940
# Epoch 9/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9180 - loss: 0.2983 - val_accuracy: 0.9237 - val_loss: 0.2770
# Epoch 10/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9223 - loss: 0.2803 - val_accuracy: 0.9270 - val_loss: 0.2626
# ----------------------
#
# --- Evaluating Model ---
# Test loss, Test acc: [0.26694098114967346, 0.9247000217437744]
# ------------------------

# %%
import os

save_path = "two_class_nn_model.keras"

model.save(save_path)
print(f"Model saved successfully at: {os.path.abspath(save_path)}")
# Out:
# Model saved successfully at: e:\deep cnn image classifier\data\DLPrac\two_class_nn_model.keras
